# %%
# !pip install transformers torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.7.14)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import torch
from transformers import pipeline
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

# %%
import pandas as pd
df = pd.read_csv('Dropbox.csv')

# %%
df = df.sample(200)

# %%
df
# Out:
#                                   reviewId  \
# 9429  e49e50bf-f9cf-439d-b46d-3e985eb05d11
# 6155  b6ef60fe-cfb5-49ca-b7d9-1201b8014f3b
# 4974  0fb0c684-0dde-4e3e-83d0-856ac85b3a05
# 5260  1f6805aa-f354-4b65-a07e-2385a3a17a81
# 1459  77efcbe6-1908-4b64-94fa-aa94cf3db545
# ...                                    ...
# 1423  7af5bcdd-52d4-431f-a5d1-8c80a3478c46
# 1400  1c9c1162-34bd-4e09-90f2-a0e047077782
# 3724  88b10028-ab6f-494e-9be5-1853d195a809
# 6652  f71fcaae-504c-44f7-b72c-106cf88b131f
# 4798  89236193-51d8-4d98-81e8-e827f323a72a
#
#                                                 content  score
# 9429                                               best      5
# 6155                                       Vry vry good      5
# 4974  Dropbox is still a great service and ones of t...      4
# 5260  Am I using this app ,inquer , access to info s...      2
# 1459  Very workable and efficient. Layered encryptio...      5
# ...                                                 ...    ...
# 1423                                       very helpful      4
# 1400                   I have rely on Dropbox for years      5
# 3724  I switched to Drive to save on cost since I wa...      4
# 6652  I've been a subscriber to Dropbox is roughly 2...      1
# 4798                                              Works      4
#
# [200 rows x 3 columns]

# %%
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")

nlp = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)

texts = list(df.content.values)
results = nlp(texts)
# Out:
# Device set to use cuda:0

# %%
for text, result, score in zip(texts, results, df.score.values):
  print('Text:', text)
  print('Result:', result)
  print('Score:', score)
# Out:
# Text: best
# Result: {'label': 'POSITIVE', 'score': 0.9997941851615906}
# Score: 5
# Text: Vry vry good
# Result: {'label': 'POSITIVE', 'score': 0.9995325803756714}
# Score: 5
# Text: Dropbox is still a great service and ones of the few that can be trusted to do cross platform consistently. But I wish they'd stay focused on their core product instead of constantly branching out in weird and confusing directions. The app's UI is kind of a mess these days when 99.9% of the time I only ever want to sync, upload, or download files, or share them with others.
# Result: {'label': 'NEGATIVE', 'score': 0.9993048906326294}
# Score: 4
# Text: Am I using this app ,inquer , access to info stored .
# Result: {'label': 'NEGATIVE', 'score': 0.9925278425216675}
# Score: 2
# Text: Very workable and efficient. Layered encryption is nice too.
# Result: {'label': 'POSITIVE', 'score': 0.9997678399085999}
# Score: 5
# Text: Doesn't alloe me to save to my device. The option does not show up after clicking on the vertical ellipsis. I fon't have access to a computer. I need tp save the documents and files.
# Result: {'label': 'NEGATIVE', 'score': 0.999432384967804}
# Score: 1
# Text: very interesting
# Result: {'label': 'POSITIVE', 'score': 0.999863862991333}
# Score: 5
# Text: Second layer security is to email I have no longer access to, cant get help with this
# Result: {'label': 'NEGATIVE', 'score': 0.9975906610488892}
# Score: 1
# Text: My account is hacked Way beyond your comprehension or abilities obviously
# Result: {'label': 'NEGATIVE', 'score': 0.9997609257698059}
# Score: 1
# Text: I had old files which don't appear any more. Do not trust this company when it comes to long term preservation of files
# Result: {'label': 'NEGATIVE', 'score': 0.999500036239624}
# Score: 1
# Text: Dropbox is just wonderful. I bought 2T and I'm very very quiet.
# Result: {'label': 'POSITIVE', 'score': 0.9998511075973511}
# Score: 5
# Text: For some reason I started getting pop up adds on my Verizon phone after installing the app. It got really intrusive. After removing the app, no more pop ups. You gave me no options so you got the boot....
# Result: {'label': 'NEGATIVE', 'score': 0.9986528158187866}
# Score: 1
# Text: awesome
# Result: {'label': 'POSITIVE', 'score': 0.9998682737350464}
# Score: 5
# Text: ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
# Text: It's Expensive. I've been using this app for over 7 years now and i have all my document in there since then but recently i got out if storage and i looked at the prices are insane for a normal person to effort and the problem is there's only 2 choices you ether chose to pay 12$ per month and 120$ per a year there's no other choice like there's should be an option where you can buy the amount of storage you need for as long as you want. Every person knows how much storage he need and buy it once
# Result: {'label': 'NEGATIVE', 'score': 0.9986153841018677}
# Score: 2
# Text: very very nice good morning
# Result: {'label': 'POSITIVE', 'score': 0.9998679161071777}
# Score: 5
# Text: iv had dropbox for sometime now but am gimp with using it i thought there was alot more but still in use
# Result: {'label': 'NEGATIVE', 'score': 0.9901789426803589}
# Score: 3
# Text: my first time, may be interested
# Result: {'label': 'POSITIVE', 'score': 0.9903165698051453}
# Score: 5
# Text: Canceled subscription Nov 6, recieved email say I was charged. Contacted Dropbox they said I never canceled. Canceled it. Now can't remove from Google pay to stop payments from recurring
# Result: {'label': 'NEGATIVE', 'score': 0.9837902188301086}
# Score: 1
# Text: Okay thanks
# Result: {'label': 'POSITIVE', 'score': 0.9998050332069397}
# Score: 5
# Text: Ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
# Text: Very good
# Result: {'label': 'POSITIVE', 'score': 0.9998520612716675}
# Score: 5
# Text: great
# Result: {'label': 'POSITIVE', 'score': 0.9998630285263062}
# Score: 5
# Text: Keeps my pictures safe
# Result: {'label': 'POSITIVE', 'score': 0.9995803236961365}
# Score: 5
# Text: I like this app to automatically transfer photos from mobile phone to my computer, no need for using cable.
# Result: {'label': 'POSITIVE', 'score': 0.9983646273612976}
# Score: 5
# Text: I love my Dropbox so much. I can get everything I need done and keep with my files in no time. U should have a Dropbox account.
# Result: {'label': 'POSITIVE', 'score': 0.9937731623649597}
# Score: 5
# Text: keep crashing and forced closed
# Result: {'label': 'NEGATIVE', 'score': 0.9825495481491089}
# Score: 1
# Text: I've been with drop box est. 2008.I put my entire career on there cloud and shared it with everyone till it robbed my music pictures and all proof of my career became impossible to get into since. 2018 my password expired, totally locking me out.it's old info like phone# and e-mail address are not able to update. Leaving all my intellectual property unreachable. unable to prove my achievements retrieve thousands of dollars in recordings, art work,songs,professionally, and pricless fam pics.ect
# Result: {'label': 'NEGATIVE', 'score': 0.9996601343154907}
# Score: 1
# Text: very reliable and fast
# Result: {'label': 'POSITIVE', 'score': 0.9998593330383301}
# Score: 5
# Text: Good apps
# Result: {'label': 'POSITIVE', 'score': 0.9998608827590942}
# Score: 5
# Text: One star is too much! how do you get rid of this scam?
# Result: {'label': 'NEGATIVE', 'score': 0.9996874332427979}
# Score: 1
# Text: Not good.
# Result: {'label': 'NEGATIVE', 'score': 0.9997939467430115}
# Score: 1
# Text: Hacked
# Result: {'label': 'NEGATIVE', 'score': 0.9994045495986938}
# Score: 1
# Text: good app
# Result: {'label': 'POSITIVE', 'score': 0.9998493194580078}
# Score: 5
# Text: Too many adds which is so disruptive.
# Result: {'label': 'NEGATIVE', 'score': 0.9995383024215698}
# Score: 3
# Text: Unparalleled! I have photos & personal documents in this cloud that have been safe for over 10 years. New phone, sync my old acct & download Dropbox and everything is there like magic. I highly recommend!
# Result: {'label': 'POSITIVE', 'score': 0.9997214674949646}
# Score: 5
# Text: Can't find cancel
# Result: {'label': 'POSITIVE', 'score': 0.8198578357696533}
# Score: 1
# Text: It very good
# Result: {'label': 'POSITIVE', 'score': 0.9998588562011719}
# Score: 5
# Text: Absolutely screw this app. It's extremely slow and forces my phone to run at max power for no reason causing it to get extremely hot. It's a fold6 so it shouldn't be doing that. Will not use again.
# Result: {'label': 'NEGATIVE', 'score': 0.9995142221450806}
# Score: 1
# Text: Very Good
# Result: {'label': 'POSITIVE', 'score': 0.9998520612716675}
# Score: 5
# Text: Easy to use and fast to work.
# Result: {'label': 'POSITIVE', 'score': 0.999653697013855}
# Score: 5
# Text: I'm using this App from Nigeria. If I lost my phone I will recover everything back. Je suis contente pour ça.
# Result: {'label': 'NEGATIVE', 'score': 0.9987874627113342}
# Score: 5
# Text: Impossible to recommend. No way to sort by file size to meet requirements. Buy Microsoft instead. That at least comes with office.
# Result: {'label': 'NEGATIVE', 'score': 0.9995982050895691}
# Score: 1
# Text: I love DropBox. No sync problems like those I have using OndDrive.
# Result: {'label': 'POSITIVE', 'score': 0.995071291923523}
# Score: 4
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 3
# Text: I never can get back in. Sad to try and collaborate & be foiled.
# Result: {'label': 'NEGATIVE', 'score': 0.9754626154899597}
# Score: 1
# Text: If I can rate it 0 I will I hate this app I can't even sign up
# Result: {'label': 'NEGATIVE', 'score': 0.9996969699859619}
# Score: 1
# Text: terrible. only wanted to get 1 file that has been sent to me....can not find it. now want to cancel and can not find the cancel option.
# Result: {'label': 'NEGATIVE', 'score': 0.9997448325157166}
# Score: 1
# Text: Wow
# Result: {'label': 'POSITIVE', 'score': 0.999592125415802}
# Score: 3
# Text: The app is difficult to use and navigate. I'm now experiencing that the navigation bars (in gesture mode) on my Samsung tablet don't disappear when viewing an image, which is extremely annoying. It worked OK about two weeks ago.
# Result: {'label': 'NEGATIVE', 'score': 0.9689282774925232}
# Score: 2
# Text: Way, way, way to many junk emails.
# Result: {'label': 'NEGATIVE', 'score': 0.9995800852775574}
# Score: 2
# Text: Wowsa! Trio is powerful!
# Result: {'label': 'POSITIVE', 'score': 0.9998781681060791}
# Score: 5
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 3
# Text: easy to navigate
# Result: {'label': 'POSITIVE', 'score': 0.9997637867927551}
# Score: 5
# Text: I AM SHOCKED at how BAD this app is - the video replay is TERRIBLE - the screen freezes and plays a different video underneath the frozen pic. I already followed the instructions to uninstall, restart, and reinstall the app - that did NOT work, and that kind of inconvenient "fix" should never even be required. I also just signed up for the free trial to get more storage space - if this isn't fixed by the end of the trial, I'm definitely not continuing with the subscription.
# Result: {'label': 'NEGATIVE', 'score': 0.9997517466545105}
# Score: 1
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 3
# Text: Best app ever but needs improvement on storage
# Result: {'label': 'NEGATIVE', 'score': 0.9916226267814636}
# Score: 4
# Text: great app
# Result: {'label': 'POSITIVE', 'score': 0.999821126461029}
# Score: 5
# Text: Paid for the upgraded version for a month. Then, I canceled my subscription so they wouldn't take a second payment, and they still took the payment out and will not refund me . I messaged customer service 30 minutes after they took the payment, and they still won't refund me. So, if you just plan on using it for a short period of time, I wouldn't recommend paying for it.
# Result: {'label': 'NEGATIVE', 'score': 0.9991224408149719}
# Score: 1
# Text: Pretty solid... =}
# Result: {'label': 'POSITIVE', 'score': 0.9998408555984497}
# Score: 5
# Text: Very helpful this app
# Result: {'label': 'POSITIVE', 'score': 0.9995681643486023}
# Score: 5
# Text: No phone support & way too expensive
# Result: {'label': 'NEGATIVE', 'score': 0.9997026324272156}
# Score: 1
# Text: keeps my shop manuals together
# Result: {'label': 'POSITIVE', 'score': 0.986084520816803}
# Score: 5
# Text: stop this . it's useless and no option to turn it off . it pops up like memories of.... stop it
# Result: {'label': 'NEGATIVE', 'score': 0.99953293800354}
# Score: 1
# Text: Been with me since I got it. Really like it.
# Result: {'label': 'POSITIVE', 'score': 0.9998408555984497}
# Score: 5
# Text: I like this
# Result: {'label': 'POSITIVE', 'score': 0.9998672008514404}
# Score: 5
# Text: nice app ease to use
# Result: {'label': 'POSITIVE', 'score': 0.999704897403717}
# Score: 5
# Text: Latest update makes it much harder to save a whole directory. Making it more tedious to save Patreon file sets, was 1 touch previously, now you have find the new save button, tap it, tap select all, create a folder on your drive, tap it, then save.
# Result: {'label': 'NEGATIVE', 'score': 0.9996355772018433}
# Score: 2
# Text: If I could give less than 1 star I would. I tried to cancel during trial period and I couldn't. So they charged me. I'm trying to cancel my dropbox account and it's impossible. I no longer have the phone it was originally purchased on. I have emailed the dropbox team 3 times to cancel and nobody responds. Shady. Still trying to cancel. Do not get this app.
# Result: {'label': 'NEGATIVE', 'score': 0.9997517466545105}
# Score: 1
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Muhammaed Mulat Successful
# Result: {'label': 'NEGATIVE', 'score': 0.7679534554481506}
# Score: 5
# Text: Make it to where your phone is safe
# Result: {'label': 'NEGATIVE', 'score': 0.9401748776435852}
# Score: 3
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Sucks
# Result: {'label': 'NEGATIVE', 'score': 0.9991297125816345}
# Score: 1
# Text: Doesn't sync well with the browser and the integration is really worse.
# Result: {'label': 'NEGATIVE', 'score': 0.9998131394386292}
# Score: 1
# Text: great software
# Result: {'label': 'POSITIVE', 'score': 0.9998536109924316}
# Score: 5
# Text: After update, upload to Dropbox from album is not as user friends before. Now I have to select the folder every time instead of going back to the last used folder and can left swipe to go back to the previous level like before. Please bring back the option to use last use folder as default like before.
# Result: {'label': 'NEGATIVE', 'score': 0.9938251972198486}
# Score: 3
# Text: the way you get around the app is very confusing to me and definitely not straightforward. Also I keep getting error message when trying to sign anything.
# Result: {'label': 'NEGATIVE', 'score': 0.9996610879898071}
# Score: 3
# Text: Have 5 Gigs space left, but can't access my photos as I'm told I've "reached my limit". Can only access if I pay the $18.99 per month! There are a lot of significant photos on it that I put there in good faith. Seems nothing can be trusted to deliver what is promised. Extremely disappointed.
# Result: {'label': 'NEGATIVE', 'score': 0.9990672469139099}
# Score: 1
# Text: Great cloud storage app, easy to use.
# Result: {'label': 'POSITIVE', 'score': 0.9993845224380493}
# Score: 5
# Text: Excellent way to organize our business's important documents & ensure shared access to the people who need it.
# Result: {'label': 'POSITIVE', 'score': 0.9998626708984375}
# Score: 5
# Text: kept all my memories in tact
# Result: {'label': 'POSITIVE', 'score': 0.9989544153213501}
# Score: 5
# Text: Lost pictures
# Result: {'label': 'NEGATIVE', 'score': 0.9996100068092346}
# Score: 2
# Text: Why I can't sign in in my Dropbox app anymore.
# Result: {'label': 'NEGATIVE', 'score': 0.9995496869087219}
# Score: 1
# Text: great program
# Result: {'label': 'POSITIVE', 'score': 0.9998695850372314}
# Score: 5
# Text: You have to have an act of congress to delete your "subscription ". I feel like I was conned in a paid subscription . The trial was confusing. Well, you got me one time, but never again.
# Result: {'label': 'NEGATIVE', 'score': 0.9989814162254333}
# Score: 1
# Text: Time will tell me if it was the best time of my life
# Result: {'label': 'POSITIVE', 'score': 0.9950278401374817}
# Score: 5
# Text: It's useful.
# Result: {'label': 'POSITIVE', 'score': 0.9998334646224976}
# Score: 4
# Text: Would please change the name. I didn't lose my files.
# Result: {'label': 'POSITIVE', 'score': 0.995329737663269}
# Score: 3
# Text: storage is expensive for pensioner. not able to delete duplicates...why?
# Result: {'label': 'NEGATIVE', 'score': 0.9990307092666626}
# Score: 3
# Text: Dropbox is a fantastic storage facility in the cloud, but it isn't cheap!
# Result: {'label': 'POSITIVE', 'score': 0.9978662133216858}
# Score: 5
# Text: Clears up space.
# Result: {'label': 'POSITIVE', 'score': 0.9994719624519348}
# Score: 3
# Text: nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998061060905457}
# Score: 4
# Text: I WISH YOUR APP & GOOGLES HAD A EASY WAY TO JUST COPY PICTURES & VIDEO INSTEAD OF MOVING THE FILES & THEN MAKING US RE ADD THE PICTURES!
# Result: {'label': 'NEGATIVE', 'score': 0.9995586276054382}
# Score: 5
# Text: ಸೂಪರ್
# Result: {'label': 'NEGATIVE', 'score': 0.697055995464325}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: It's good but app in priced is just expensive
# Result: {'label': 'NEGATIVE', 'score': 0.9414598941802979}
# Score: 3
# Text: Good one tbb
# Result: {'label': 'POSITIVE', 'score': 0.9997747540473938}
# Score: 5
# Text: Data breach much, storage and feature given not much
# Result: {'label': 'NEGATIVE', 'score': 0.9994334578514099}
# Score: 1
# Text: Excellent
# Result: {'label': 'POSITIVE', 'score': 0.9998434782028198}
# Score: 4
# Text: can't cancel subscription
# Result: {'label': 'POSITIVE', 'score': 0.9883651733398438}
# Score: 1
# Text: not wark
# Result: {'label': 'POSITIVE', 'score': 0.9981132745742798}
# Score: 5
# Text: I was signed out of all my devices and can't sign back in and can't even get anyone on the phone. Your only option is a recorded message and a chat bot. They tell you to log in to request help but if you can't log in you're screwed
# Result: {'label': 'NEGATIVE', 'score': 0.9995763897895813}
# Score: 1
# Text: sometimes files don't start to download and other times video files are randomly corrupted when downloaded.
# Result: {'label': 'NEGATIVE', 'score': 0.9977783560752869}
# Score: 2
# Text: WAS using Google Drive until issues set in. Dropbox is FAR more reliable.
# Result: {'label': 'NEGATIVE', 'score': 0.9639198780059814}
# Score: 5
# Text: grey app supar
# Result: {'label': 'NEGATIVE', 'score': 0.9994981288909912}
# Score: 5
# Text: Was working but then I upgraded to pay acct and mow I cant even get in
# Result: {'label': 'NEGATIVE', 'score': 0.9973534345626831}
# Score: 2
# Text: I try to get into my drop box and can't get past this pay 11. upgrade subscription it simple won't let me in why is this I think it's bull
# Result: {'label': 'NEGATIVE', 'score': 0.9988693594932556}
# Score: 1
# Text: This is a great app But why i give this 2 star? The waitibg to upload is taking so long to start loading again,this should be fix
# Result: {'label': 'NEGATIVE', 'score': 0.9959495067596436}
# Score: 2
# Text: Great App
# Result: {'label': 'POSITIVE', 'score': 0.999821126461029}
# Score: 5
# Text: It hangs but stores more files
# Result: {'label': 'NEGATIVE', 'score': 0.9847815036773682}
# Score: 3
# Text: I need very much Dropbox.it it's very help me in My job and also My files and My documents safe it.
# Result: {'label': 'POSITIVE', 'score': 0.867255449295044}
# Score: 5
# Text: Not user friendly
# Result: {'label': 'NEGATIVE', 'score': 0.9996281862258911}
# Score: 2
# Text: Nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
# Text: Yet to try. Cause Google cloud had over load
# Result: {'label': 'NEGATIVE', 'score': 0.9992654919624329}
# Score: 5
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: I have cleared many files and photos yet my Dropbox never goes down. Can I transfer info from DropBox to Google 1?
# Result: {'label': 'POSITIVE', 'score': 0.7361972332000732}
# Score: 1
# Text: Dropbox is my favorite cloud service. I still use other services, but Dropbox has the best interface (in my humble opinion).
# Result: {'label': 'POSITIVE', 'score': 0.9995057582855225}
# Score: 5
# Text: Dropbox always was, & still is one of the best online storage services. Then I made the mistake of believing they no longer had a free version. Thankfully they still do. Thank you for informing me.
# Result: {'label': 'POSITIVE', 'score': 0.9991921782493591}
# Score: 5
# Text: I've been using the free Dropbox app, and Dropbox Pro for years, I love Dropbox!
# Result: {'label': 'POSITIVE', 'score': 0.9993556141853333}
# Score: 5
# Text: Dropbox keeps crashing and I am unable to find support for the issue.
# Result: {'label': 'NEGATIVE', 'score': 0.9997199177742004}
# Score: 1
# Text: i want to download all at one time
# Result: {'label': 'NEGATIVE', 'score': 0.7933558225631714}
# Score: 2
# Text: Lovely
# Result: {'label': 'POSITIVE', 'score': 0.9998601675033569}
# Score: 5
# Text: When you changed the layout of the recent folder you ruined it. Now it's a mess.
# Result: {'label': 'NEGATIVE', 'score': 0.9997901320457458}
# Score: 2
# Text: They want too much of our data
# Result: {'label': 'NEGATIVE', 'score': 0.9996365308761597}
# Score: 1
# Text: Still waiting for the ability to upload folders. I found a support forum thread from 2017 where a dropbox person said they would forward the request to the dev team. Has the dev team been fired, are they sleeping or simply not interested in adding one of the most useful features to the app?
# Result: {'label': 'NEGATIVE', 'score': 0.999171257019043}
# Score: 1
# Text: Paying for PREMIUM, just for nothing to work the way it's supposed to.
# Result: {'label': 'NEGATIVE', 'score': 0.9995155334472656}
# Score: 1
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: The update from 20 June 2024 is a regression in UI. It no longer remembers the last folder where an upload occurred. There also does not seem be be a way to create a folder when sending/sharing a photo to Dropbox from Gallery app.
# Result: {'label': 'NEGATIVE', 'score': 0.9997698664665222}
# Score: 3
# Text: Great interface between all operating platforms!
# Result: {'label': 'POSITIVE', 'score': 0.999829888343811}
# Score: 5
# Text: keeps crashing
# Result: {'label': 'NEGATIVE', 'score': 0.981321394443512}
# Score: 1
# Text: Ok
# Result: {'label': 'POSITIVE', 'score': 0.9997851252555847}
# Score: 5
# Text: Very good app but I can't send file to anybody due to MB
# Result: {'label': 'NEGATIVE', 'score': 0.9447646737098694}
# Score: 5
# Text: the app is just okay. could be more slick and sexy.
# Result: {'label': 'POSITIVE', 'score': 0.999800980091095}
# Score: 3
# Text: A little pricey, but it works well
# Result: {'label': 'POSITIVE', 'score': 0.999852180480957}
# Score: 4
# Text: My files were well taken care of
# Result: {'label': 'POSITIVE', 'score': 0.9985896944999695}
# Score: 5
# Text: cool :)
# Result: {'label': 'POSITIVE', 'score': 0.9997645020484924}
# Score: 5
# Text: Oct 23: HATE the newer UI. Kills usability! Update April 24: Still hate app UI. Trades pretty, expansice graphics for valuable screen space. Makes app nearly unusable for business use. OneDrive app is far superior. Update June 24: app unacceptable slow when simply sending a Share invite; app locks up and unavailable for other operations - as I'm sitting in a meeting with a client. How's this supposed to work?
# Result: {'label': 'NEGATIVE', 'score': 0.9978417158126831}
# Score: 1
# Text: Gooda secure appy
# Result: {'label': 'POSITIVE', 'score': 0.9997685551643372}
# Score: 4
# Text: Issues to login. I love use Dropbox, but Since the last update of my pixel 6 to android beta 15 I am having problems logging into the dropbox app. What is the solution? Ty
# Result: {'label': 'NEGATIVE', 'score': 0.9987885355949402}
# Score: 5
# Text: Perfect 👌app
# Result: {'label': 'POSITIVE', 'score': 0.9998273849487305}
# Score: 5
# Text: Lately the app simply won't sync properly. I upload files to Dropbox on my desktop and most of them never appear on my phone app. Since that is the main thing I use Dropbox for the app is now virtually useless. Unfortunately, in the last couple of years I've seen too many glitches of various types in this app. For a cloud-based app to be useful it needs to work CONSISTENTLY and this one.... doesn't. I'm tired of having to troubleshoot this app to make it work. Ugh...
# Result: {'label': 'NEGATIVE', 'score': 0.999797523021698}
# Score: 1
# Text: Love it I keep all my memories I want hidden or I don't want to loose
# Result: {'label': 'POSITIVE', 'score': 0.9998332262039185}
# Score: 5
# Text: Very effective way to keep access to important docs and photos.
# Result: {'label': 'POSITIVE', 'score': 0.9997925162315369}
# Score: 4
# Text: wonderful service
# Result: {'label': 'POSITIVE', 'score': 0.9998819828033447}
# Score: 5
# Text: I have cancelled the membership 2 weeks ago and it won't stop trying to charge my card! this App Will Make Your Phone Crash n Try To get Billed over n over for $127 0- Stars for this APP!
# Result: {'label': 'NEGATIVE', 'score': 0.9917823076248169}
# Score: 1
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 4
# Text: I've used Dropbox for over a decade. I installed this app to find a file. I'd much rather delete this app than deal with a service sending multiple repetitive SPAM notifications and emails about upgrading. That's just a garbage way to annoy your users. There are more effective ways to advertise, try something else and be a better service
# Result: {'label': 'NEGATIVE', 'score': 0.9997308850288391}
# Score: 1
# Text: good to have it ♥️
# Result: {'label': 'POSITIVE', 'score': 0.9998475313186646}
# Score: 4
# Text: Cant tell me even how much space a folder is taking? and u want me to upgrade? 🤣
# Result: {'label': 'NEGATIVE', 'score': 0.9994874000549316}
# Score: 1
# Text: 5 etoile
# Result: {'label': 'POSITIVE', 'score': 0.9912043213844299}
# Score: 5
# Text: Very Convinient and user friendly . i get to access all my documents wherever I am.
# Result: {'label': 'POSITIVE', 'score': 0.9897884726524353}
# Score: 5
# Text: My biggest problem is that it has an offline availability setting that only works 10% of the time. Everytime I need to do critical work without internet, I find that I can't access the files that were supposed to be available. Furthermore, I can't get help with the problem.
# Result: {'label': 'NEGATIVE', 'score': 0.9995294809341431}
# Score: 1
# Text: I can't upgrade my account to 2 TB
# Result: {'label': 'NEGATIVE', 'score': 0.9969711303710938}
# Score: 1
# Text: incredible
# Result: {'label': 'POSITIVE', 'score': 0.9998753070831299}
# Score: 5
# Text: Dropbox is number one and a must have app, but only too expensive for people who are not employed
# Result: {'label': 'NEGATIVE', 'score': 0.9922661185264587}
# Score: 5
# Text: I like. It's good for what it does.
# Result: {'label': 'POSITIVE', 'score': 0.9998661279678345}
# Score: 5
# Text: all
# Result: {'label': 'POSITIVE', 'score': 0.9902591705322266}
# Score: 5
# Text: I regret purchasing this. the user face is soo unfriendly. it's a navigational nightmare.
# Result: {'label': 'NEGATIVE', 'score': 0.9995952248573303}
# Score: 1
# Text: Best backup cloud
# Result: {'label': 'POSITIVE', 'score': 0.9981030225753784}
# Score: 5
# Text: don't know how it woks in mobile😭
# Result: {'label': 'NEGATIVE', 'score': 0.9986661672592163}
# Score: 1
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
# Text: awesome saving all videos, images n documents n others thing. that hold all memories n has this with all different phones still working great I pay for 1 T memories to hold I only have very small amounts putting in Dropbox n very plenty more to add it I love Dropbox n only little problem is that I can't share my image to email or messages to share it stuck that no one can't see my images from Dropbox. need fix that bec other people don't have Dropbox that is 1 my big problem!!! thk
# Result: {'label': 'NEGATIVE', 'score': 0.7158529758453369}
# Score: 5
# Text: It's good 👍
# Result: {'label': 'POSITIVE', 'score': 0.9998725652694702}
# Score: 5
# Text: Fantastisch
# Result: {'label': 'POSITIVE', 'score': 0.9955614805221558}
# Score: 5
# Text: 20 minute logging in process failed every single time. Typing in the correct security code registered as incorrect, and reloading the login screen to generate a new code suddenly registered the previously correct account details as incorrect. App had to be restarted each attempt and the process never worked. I expect I'll also be harassed with ads now wven though I ticked to not contact me with marketing
# Result: {'label': 'NEGATIVE', 'score': 0.9997714161872864}
# Score: 1
# Text: perfect ap
# Result: {'label': 'POSITIVE', 'score': 0.9998348951339722}
# Score: 5
# Text: Drop Box has been a totally great add-on with business with multiple device capabilities.
# Result: {'label': 'POSITIVE', 'score': 0.9993295669555664}
# Score: 5
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Best toool
# Result: {'label': 'POSITIVE', 'score': 0.9887624382972717}
# Score: 5
# Text: I'm hoping this will clear up my matter in Google . And give the room I need to keep enjoying my google and google family
# Result: {'label': 'POSITIVE', 'score': 0.9747098088264465}
# Score: 5
# Text: very nice 👍🙂
# Result: {'label': 'POSITIVE', 'score': 0.9998577833175659}
# Score: 5
# Text: It soo laggy so I can't literally use application, every screen just freezes and doesn't handle any touches
# Result: {'label': 'NEGATIVE', 'score': 0.999761164188385}
# Score: 1
# Text: very handy
# Result: {'label': 'POSITIVE', 'score': 0.9995710253715515}
# Score: 4
# Text: The app won't upload anything large in cell data, it's constantly on waiting to upload. I can upload to wetransfer in a browser and have it completed while Dropbox is still sitting there waiting.
# Result: {'label': 'NEGATIVE', 'score': 0.9991939663887024}
# Score: 1
# Text: I've been a long-time Dropbox user, but their recent practices are disappointing. The constant barrage of upgrade emails is harassment. The advertised storage limits are deceptive; file sizes are manipulated to make you run out of space quickly, pushing you to pay for more storage. This feels like a deliberate attempt to make users spend money. Dropbox's approach to storage management and aggressive marketing is frustrating. I would not recommend Dropbox for fair and transparent cloud storage
# Result: {'label': 'NEGATIVE', 'score': 0.9994773268699646}
# Score: 1
# Text: Awesome Rossum
# Result: {'label': 'POSITIVE', 'score': 0.9998340606689453}
# Score: 5
# Text: If you can't even do the thing you're made for, delete your website
# Result: {'label': 'NEGATIVE', 'score': 0.999559223651886}
# Score: 1
# Text: Never used this application.
# Result: {'label': 'NEGATIVE', 'score': 0.9885565042495728}
# Score: 1
# Text: Lawda hai ap p mat download karna
# Result: {'label': 'NEGATIVE', 'score': 0.8226800560951233}
# Score: 1
# Text: It is very good storage.
# Result: {'label': 'POSITIVE', 'score': 0.9997153878211975}
# Score: 5
# Text: Dropbox is the gold standard for cloud based storage.
# Result: {'label': 'POSITIVE', 'score': 0.9975153207778931}
# Score: 5
# Text: I have had this app for 12 years and it's served all my writing storage needs. I love Dropbox!
# Result: {'label': 'POSITIVE', 'score': 0.9992645382881165}
# Score: 4
# Text: TURN A RECORDS LLC APPROVES DROPBOX
# Result: {'label': 'POSITIVE', 'score': 0.986829936504364}
# Score: 5
# Text: Love This App
# Result: {'label': 'POSITIVE', 'score': 0.9998668432235718}
# Score: 5
# Text: I like the app.
# Result: {'label': 'POSITIVE', 'score': 0.9996746778488159}
# Score: 5
# Text: nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
# Text: awesome !!!!
# Result: {'label': 'POSITIVE', 'score': 0.9998716115951538}
# Score: 5
# Text: Nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998061060905457}
# Score: 5
# Text: Great 👌
# Result: {'label': 'POSITIVE', 'score': 0.9997692704200745}
# Score: 2
# Text: Latest update has changed the appearance of the file folders and added features. Might be good but the problem is the picture thumbnails now disappear, reappear and disappear randomly. If I'm selecting pictures to download, the first picture that I select makes all the thumbnails disappear. Still no file duplicate software and moving more than 50 pictures from one folder to another often fails or causes the application to freeze up. About ready to give up paying for Dropbox.
# Result: {'label': 'NEGATIVE', 'score': 0.999421238899231}
# Score: 3
# Text: I love how you can take and make file folders for your important pictures.
# Result: {'label': 'POSITIVE', 'score': 0.9997873902320862}
# Score: 5
# Text: Dropbox is a horrible company. I have an account that has been hacked and is still sending malicious emails. I have emailed them several times asking them to delete the account. They said they are looking into though because it was hacked and I cannot log into the account they cannot delete it. Meanwhile it's been four days since I first contacted their help email and cannot find a single phone number to call. THIS IS NOT AN ETHICAL COMPANY, STAY AWAY.
# Result: {'label': 'NEGATIVE', 'score': 0.999593198299408}
# Score: 1
# Text: best
# Result: {'label': 'POSITIVE', 'score': 0.9997941851615906}
# Score: 5
# Text: Perfect but expensive when you want more than 2GB
# Result: {'label': 'POSITIVE', 'score': 0.6652188301086426}
# Score: 3
# Text: very helpful
# Result: {'label': 'POSITIVE', 'score': 0.9997938275337219}
# Score: 4
# Text: I have rely on Dropbox for years
# Result: {'label': 'NEGATIVE', 'score': 0.9521757364273071}
# Score: 5
# Text: I switched to Drive to save on cost since I wasn't using that much online storage space (and for practicality). Still useful for quick stuff.
# Result: {'label': 'NEGATIVE', 'score': 0.5252271890640259}
# Score: 4
# Text: I've been a subscriber to Dropbox is roughly 2015 it wasn't until 2017 2 hours no longer able to log into my Dropbox account on any device other than my tablet. It instructed me to change my password but never emailed thee reset to my email junk folder or otherwise. I've been dependant and restricted to my tablet since 2017. Recently I purchased a 1 TB microSD card and now I think I'm ready to remove my paid subscription due to such lousy customer support.
# Result: {'label': 'NEGATIVE', 'score': 0.9994338154792786}
# Score: 1
# Text: Works
# Result: {'label': 'POSITIVE', 'score': 0.9998278617858887}
# Score: 4

# %%
df['sentiment'] = [r['label'] for r in results]

# %%
df
# Out:
#                                   reviewId  \
# 9429  e49e50bf-f9cf-439d-b46d-3e985eb05d11
# 6155  b6ef60fe-cfb5-49ca-b7d9-1201b8014f3b
# 4974  0fb0c684-0dde-4e3e-83d0-856ac85b3a05
# 5260  1f6805aa-f354-4b65-a07e-2385a3a17a81
# 1459  77efcbe6-1908-4b64-94fa-aa94cf3db545
# ...                                    ...
# 1423  7af5bcdd-52d4-431f-a5d1-8c80a3478c46
# 1400  1c9c1162-34bd-4e09-90f2-a0e047077782
# 3724  88b10028-ab6f-494e-9be5-1853d195a809
# 6652  f71fcaae-504c-44f7-b72c-106cf88b131f
# 4798  89236193-51d8-4d98-81e8-e827f323a72a
#
#                                                 content  score sentiment
# 9429                                               best      5  POSITIVE
# 6155                                       Vry vry good      5  POSITIVE
# 4974  Dropbox is still a great service and ones of t...      4  NEGATIVE
# 5260  Am I using this app ,inquer , access to info s...      2  NEGATIVE
# 1459  Very workable and efficient. Layered encryptio...      5  POSITIVE
# ...                                                 ...    ...       ...
# 1423                                       very helpful      4  POSITIVE
# 1400                   I have rely on Dropbox for years      5  NEGATIVE
# 3724  I switched to Drive to save on cost since I wa...      4  NEGATIVE
# 6652  I've been a subscriber to Dropbox is roughly 2...      1  NEGATIVE
# 4798                                              Works      4  POSITIVE
#
# [200 rows x 4 columns]
